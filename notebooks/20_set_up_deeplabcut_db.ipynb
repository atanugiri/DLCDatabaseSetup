# %% [markdown]
# # Set up deeplabcut database table

# %% [markdown]
# ## Connect to database

# %%
import os
import psycopg2
import pandas as pd
import platform

host = "localhost" if platform.system() == "Windows" else "129.108.49.49"

conn = psycopg2.connect(dbname="deeplabcut_db", user="postgres", password="1234", host=host, port="5432")

cursor = conn.cursor()

print(conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 8
#       4 import platform
#       6 host = "localhost" if platform.system() == "Windows" else "129.108.49.49"
# ----> 8 conn = psycopg2.connect(dbname="deeplabcut_db", user="postgres", password="1234", host=host, port="5432")
#      10 cursor = conn.cursor()
#      12 print(conn)
#
# File ~/miniconda3/envs/gastric/lib/python3.10/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "129.108.49.49", port 5432 failed: Operation timed out
# 	Is the server running on that host and accepting TCP/IP connections?

# %% [markdown]
# ## Create table

# %%
cursor.execute("CREATE TABLE IF NOT EXISTS dlc_table (id SERIAL PRIMARY KEY);")
conn.commit()

# %% [markdown]
# ## Add other features to the table

# %%
# Add new columns to the table (if they don't already exist)
alter_commands = [
    "ALTER TABLE dlc_table ADD COLUMN IF NOT EXISTS video_name TEXT",
    "ALTER TABLE dlc_table ADD COLUMN IF NOT EXISTS num_frames INTEGER",
    "ALTER TABLE dlc_table ADD COLUMN IF NOT EXISTS frame_rate FLOAT",
    "ALTER TABLE dlc_table ADD COLUMN IF NOT EXISTS genotype TEXT",
    "ALTER TABLE dlc_table ADD COLUMN IF NOT EXISTS task TEXT",
    "ALTER TABLE dlc_table ADD COLUMN IF NOT EXISTS health TEXT",
    "ALTER TABLE dlc_table ADD COLUMN IF NOT EXISTS name TEXT",
    "ALTER TABLE dlc_table ADD COLUMN IF NOT EXISTS date TIMESTAMP",
    "ALTER TABLE dlc_table ADD COLUMN IF NOT EXISTS video_width INTEGER",
    "ALTER TABLE dlc_table ADD COLUMN IF NOT EXISTS video_height INTEGER",
    "ALTER TABLE dlc_table ADD COLUMN IF NOT EXISTS csv_file_path TEXT"
]

for command in alter_commands:
    cursor.execute(command)

conn.commit()

# %%
alter_command = "ALTER TABLE dlc_table ADD COLUMN IF NOT EXISTS dose_mult SMALLINT"
cursor.execute(alter_command)
conn.commit()

# %%
q = "SELECT * FROM dlc_table LIMIT 1"
df = pd.read_sql(q, conn)
print(df.columns)

# q = """
# SELECT id, video_name, genotype, task, maze, modulation, 
# dose_mult, center_x, center_y FROM dlc_table WHERE genotype='white' 
# AND maze<>4 ORDER BY id 
# """

# df = pd.read_sql(q, conn)
# df.to_csv("dlc_table.csv", index=False)
# Out:
# Index(['video_name', 'num_frames', 'frame_rate', 'trial_length', 'video_width',
#        'video_height', 'genotype', 'task', 'health', 'name', 'date', 'maze',
#        'distance', 'velocity', 'acceleration', 'curvature', 'acc_outlier',
#        'jerk_outlier', 'mean_curv', 'id', 'csv_file_path', 'modulation',
#        'dose_mult', 'center_x', 'center_y'],
#       dtype='object')
# /var/folders/_n/c65sg0c951g6vgwcpzsdc2tc0000gn/T/ipykernel_4122/869489361.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(q, conn)
